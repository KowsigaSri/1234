# %% [markdown]
# <a href="https://colab.research.google.com/github/KowsigaSri/1234/blob/main/Copy_of_day1_python_kowsi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Writing and executing a basic Python script.

# %%
print("hello,data science")
# Out:
# hello,data science

# %% [markdown]
# Creating and storing customer information using Python variables.

# %%
customer_name = "john"
customer_age = "28"
customer_balance = "120"
print("Customer:",customer_name)
print("age:",customer_age)
print("balance:",customer_balance)
# Out:
# Customer: john
# age: 28
# balance: 120

# %% [markdown]
# Performing basic mathematical operations to calculate a product discount.

# %%
product_price = 200
discount = product_price * 0.10 # 10% discount
final_price = product_price - discount
print("Final Price after Discount:", final_price)
# Out:
# Final Price after Discount: 180.0

# %% [markdown]
# Storing daily sales data in a NumPy array.

# %%
import numpy as np
sales = np.array([150, 200, 250, 300, 400, 350, 500]) # Sales for each day
print("Sales Data:", sales)
# Out:
# Sales Data: [150 200 250 300 400 350 500]

# %% [markdown]
# Calculating mean, maximum, and minimum sales.

# %%
print("Average Sales:", np.mean(sales))
print("Highest Sale:", np.max(sales))
print("Lowest Sale:", np.min(sales))
# Out:
# Average Sales: 307.14285714285717
# Highest Sale: 500
# Lowest Sale: 150

# %% [markdown]
# Creating a table-like structure using Pandas.

# %%
import pandas as pd
data = {
"Customer": ["Alice", "Bob", "Charlie"],
"Age": [25, 30, 35],
"Amount Spent": [120, 200, 150]
         }
df = pd.DataFrame(data)
print(df)
# Out:
#   Customer  Age  Amount Spent
# 0    Alice   25           120
# 1      Bob   30           200
# 2  Charlie   35           150

# %% [markdown]
# Uploading and reading a CSV file in Pandas.

# %%
from google.colab import files
uploaded = files.upload() # Upload your CSV file
df = pd.read_csv("123.csv") # Replace with your file name
df.head()
# Out:
#      <input type="file" id="files-0d2f4563-29e7-4c2a-856d-70781a942def" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d2f4563-29e7-4c2a-856d-70781a942def">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Selecting customers who spent more than $150.

# %%
high_spenders = df[df["Amount Spent"] > 150]
print(high_spenders)
# Out:
#   Customer  Age  Amount Spent
# 1      Bob   30           200

# %% [markdown]
# Sorting customers from highest to lowest spending.

# %%
df_sorted = df.sort_values(by="Amount Spent", ascending=False)
print(df_sorted)
# Out:
#   Customer  Age  Amount Spent
# 1      Bob   30           200
# 2  Charlie   35           150
# 0    Alice   25           120

# %% [markdown]
# Adding Loyalty Points based on spending.

# %%
df["Loyalty Points"] = df["Amount Spent"] // 10
print(df)
# Out:
#   Customer  Age  Amount Spent  Loyalty Points
# 0    Alice   25           120              12
# 1      Bob   30           200              20
# 2  Charlie   35           150              15

# %% [markdown]
# Exporting cleaned data as a CSV file.

# %%
df.to_csv("cleaned_customer_data.csv", index=False)
files.download("cleaned_customer_data.csv") # Download the file

# %% [markdown]
# Create and store patient details such as name, age, and BMI using Python variables.

# %%
patient_name = "Alice"  # Replace with the patient's name
patient_age = 30       # Replace with the patient's age
patient_bmi = 22.5     # Replace with the patient's BMI

print("Patient Name:", patient_name)
print("Patient Age:", patient_age)
print("Patient BMI:", patient_bmi)
# Out:
# Patient Name: Alice
# Patient Age: 30
# Patient BMI: 22.5

# %% [markdown]
#  Write a program to determine the BMI category of a patient based on their BMI value.

# %%
patient_bmi = 22.5  # Replace with the actual patient's BMI

if patient_bmi < 18.5:
    bmi_category = "Underweight"
elif 18.5 <= patient_bmi < 25:
    bmi_category = "Normal Weight"
elif 25 <= patient_bmi < 30:
    bmi_category = "Overweight"
else:
    bmi_category = "Obese"

print("BMI Category:", bmi_category)
# Out:
# BMI Category: Normal Weight

# %% [markdown]
# Store a week's heart rate readings in a NumPy array and calculate the average, highest, and lowest heart rate.

# %%
import numpy as np

# Heart rate readings for a week
heart_rates = np.array([72, 75, 78, 80, 76, 74, 77])

# Calculate average, highest, and lowest heart rate
average_hr = np.mean(heart_rates)
highest_hr = np.max(heart_rates)
lowest_hr = np.min(heart_rates)

# Print the results
print("Average Heart Rate:", average_hr)
print("Highest Heart Rate:", highest_hr)
print("Lowest Heart Rate:", lowest_hr)
# Out:
# Average Heart Rate: 76.0
# Highest Heart Rate: 80
# Lowest Heart Rate: 72

# %% [markdown]
# Create a Pandas DataFrame to store patient details, including name, age, and cholesterol levels.

# %%
import pandas as pd

# Sample patient data
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'Cholesterol': [180, 200, 190, 220]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#       Name  Age  Cholesterol
# 0    Alice   25          180
# 1      Bob   30          200
# 2  Charlie   35          190
# 3    David   40          220

# %% [markdown]
#  Filter patients who have cholesterol levels above a certain threshold.

# %%
import pandas as pd

# Sample patient data (replace with your actual data)
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'Cholesterol': [180, 200, 190, 220]
}
df = pd.DataFrame(data)

# Set the cholesterol threshold
threshold = 190

# Filter the DataFrame
high_cholesterol_patients = df[df['Cholesterol'] > threshold]

# Display the filtered DataFrame
print(high_cholesterol_patients)
# Out:
#     Name  Age  Cholesterol
# 1    Bob   30          200
# 3  David   40          220

# %% [markdown]
# Sort patients based on their BMI from highest to lowest.

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'BMI': [22.5, 28.1, 24.9]  # Replace with actual BMI values
}
df = pd.DataFrame(data)
df_sorted = df.sort_values(by="BMI", ascending=False)
print(df_sorted)
# Out:
#       Name  Age   BMI
# 1      Bob   30  28.1
# 2  Charlie   35  24.9
# 0    Alice   25  22.5

# %% [markdown]
# Add a column to classify patients as "Low", "Medium", or "High" risk based on BMI and cholesterol levels.

# %%
import pandas as pd

# Sample patient data (replace with your actual data)
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'BMI': [22.5, 28.1, 24.9, 32.2],
    'Cholesterol': [180, 200, 190, 220]
}
df = pd.DataFrame(data)

# Function to classify risk
def classify_risk(row):
    if row['BMI'] >= 30 or row['Cholesterol'] >= 240:
        return "High"
    elif 25 <= row['BMI'] < 30 or 200 <= row['Cholesterol'] < 240:
        return "Medium"
    else:
        return "Low"

# Apply the function to create the 'Risk' column
df['Risk'] = df.apply(classify_risk, axis=1)

# Display the DataFrame with the new column
print(df)
# Out:
#       Name  Age   BMI  Cholesterol    Risk
# 0    Alice   25  22.5          180     Low
# 1      Bob   30  28.1          200  Medium
# 2  Charlie   35  24.9          190     Low
# 3    David   40  32.2          220    High

# %% [markdown]
# Export the cleaned patient data as a CSV file for further medical analysis.

# %%
df.to_csv("cleaned_patient_data.csv", index=False)
from google.colab import files
files.download("cleaned_patient_data.csv") # Download the file
